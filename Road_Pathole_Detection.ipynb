# %% [markdown]
# <a href="https://colab.research.google.com/github/Chanura04/AI-Powered-Road-Pothole-Detection/blob/main/Road_Pathole_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Kaggle API
# !pip install kaggle

# Authenticate with your Kaggle account
import os
os.environ['KAGGLE_USERNAME'] = "chanurakarunanayake"
os.environ['KAGGLE_KEY'] = "KGAT_03d4534f9801ecbc960d06f971dfdbfe"

# Download dataset directly into Colab
# !kaggle datasets download -d chitholian/annotated-potholes-dataset -p /content/potholes_dataset

# Unzip
# !unzip /content/potholes_dataset/annotated-potholes-dataset.zip -d /content/potholes_dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/chitholian/annotated-potholes-dataset
# License(s): DbCL-1.0
# ...
#   0% 0.00/45.9M [00:00<?, ?B/s]
# 100% 45.9M/45.9M [00:00<00:00, 1.35GB/s]
# Archive:  /content/potholes_dataset/annotated-potholes-dataset.zip
#   inflating: /content/potholes_dataset/README.md
#   inflating: /content/potholes_dataset/annotated-images/img-1.jpg
#   inflating: /content/potholes_dataset/annotated-images/img-1.xml
#   inflating: /content/potholes_dataset/annotated-images/img-10.jpg
#   inflating: /content/potholes_dataset/annotated-images/img-10.xml
#   inflating: /content/potholes_dataset/annotated-images/img-100.jpg
#   inflating: /content/potholes_dataset/annotated-images/img-100.xml
#   inflating: /content/potholes_dataset/annotated-images/img-101.jpg
#   inflating: /content/potholes_dataset/annotated-images/img-101.xml
#   inflating: /content/potholes_dataset/annotated-images/img-102.jpg
#   inflating: /content/potholes_dataset/annotated-images/img-102.xml
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os

# --- Add these libraries ---
import json
import cv2
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# This makes plots appear in the notebook
# %matplotlib inline

# %%
datasaet="/content/potholes_dataset"

# %%
image_path = os.path.join(datasaet, 'annotated-images', 'img-1.jpg')
image = cv2.imread(image_path)
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.title(f"Ground Truth for: {image_rgb}")
plt.axis('off')
plt.show()

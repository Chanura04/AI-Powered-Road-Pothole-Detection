# %%
# !pip install ultralytics
# !pip install opencv-python==4.8.0.74
# !pip install wandb
# Out:
# Requirement already satisfied: ultralytics in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (8.3.251)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (12.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (7.2.1)
# Requirement already satisfied: polars>=0.20.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (1.37.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from polars>=0.20.0->ultralytics) (1.37.0)
# Requirement already satisfied: six>=1.5 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (2026.1.0)
# Requirement already satisfied: setuptools in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chanura\anaconda3\envs\python312\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO

# %%
# import ultralytics
# print(ultralytics.__version__)

# %%
# Enter training folder
# %cd /home/oracl4/project/RoadDamageDetection/training

# %%
# !ls dataset/rddJapanIndiaFiltered/

# %%
# Change the datasets_dir value if you found path issue
# !yolo settings
# !gedit ~/.config/Ultralytics/settings.yaml

# %%
# Project Name
_project = "runs/RDD_JapanIndia"
_name = "Baseline_YOLOv8Small_Filtered"
_data = "C:\\GithubProjects\\AI-Powered-Road-Pothole-Detection\\test\\data.yaml"

# Epoch and warmup epoch
_epoch = 100
_warmup_epochs = int(_epoch*0.05)

model = YOLO('yolov8s.pt')
results = model.train(data=_data,
                      epochs=_epoch,
                      warmup_epochs=_warmup_epochs,
                      batch=32,
                      imgsz=640,
                      save_period=10,
                      workers=1,
                      project=_project,
                      name=_name,
                      seed=1337,
                      cos_lr=True,
                      mosaic=0.0,
                      
)
# Out:
# Ultralytics 8.3.251  Python-3.12.7 torch-2.9.1+cpu CPU (AMD Ryzen 7 7445HS w/ Radeon 740M Graphics)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=Baseline_YOLOv8Small_Filtered3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/RDD_JapanIndia, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\runs\detect\runs\RDD_JapanIndia\Baseline_YOLOv8Small_Filtered3, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1337, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=1, workspace=None
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\engine\trainer.py:652, in BaseTrainer.get_dataset(self)
#     646 elif str(self.args.data).rsplit(".", 1)[-1] in {"yaml", "yml"} or self.args.task in {
#     647     "detect",
#     648     "segment",
#     649     "pose",
#     650     "obb",
#     651 }:
# --> 652     data = check_det_dataset(self.args.data)
#     653     if "yaml_file" in data:
#
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\data\utils.py:424, in check_det_dataset(dataset, autodownload)
#     423 if "names" in data and "nc" in data and len(data["names"]) != data["nc"]:
# --> 424     raise SyntaxError(emojis(f"{dataset} 'names' length {len(data['names'])} and 'nc: {data['nc']}' must match."))
#     425 if "names" not in data:
#
# SyntaxError: C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\data.yaml 'names' length 4 and 'nc: 1' must match.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 11
#       8 _warmup_epochs = int(_epoch*0.05)
#      10 model = YOLO('yolov8s.pt')
# ---> 11 results = model.train(data=_data,
#      12                       epochs=_epoch,
#      13                       warmup_epochs=_warmup_epochs,
#      14                       batch=32,
#      15                       imgsz=640,
#      16                       save_period=10,
#      17                       workers=1,
#      18                       project=_project,
#      19                       name=_name,
#      20                       seed=1337,
#      21                       cos_lr=True,
#      22                       mosaic=0.0,
#      23
#      24 )
#
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\engine\model.py:769, in Model.train(self, trainer, **kwargs)
#     766 if args.get("resume"):
#     767     args["resume"] = self.ckpt_path
# --> 769 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     770 if not args.get("resume"):  # manually set model only if not resuming
#     771     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\models\yolo\detect\train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection models.
#      57
#      58     Args:
#    (...)     61         _callbacks (list, optional): List of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\engine\trainer.py:184, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     182 self.model = check_model_file_from_stem(self.args.model)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     183 with torch_distributed_zero_first(LOCAL_RANK):  # avoid auto-downloading dataset multiple times
# --> 184     self.data = self.get_dataset()
#     186 self.ema = None
#     188 # Optimization utils init
#
# File ~\anaconda3\envs\python312\Lib\site-packages\ultralytics\engine\trainer.py:656, in BaseTrainer.get_dataset(self)
#     654             self.args.data = data["yaml_file"]  # for validating 'yolo train data=url.zip' usage
#     655 except Exception as e:
# --> 656     raise RuntimeError(emojis(f"Dataset '{clean_url(self.args.data)}' error ❌ {e}")) from e
#     657 if self.args.single_cls:
#     658     LOGGER.info("Overriding class names with single class.")
#
# RuntimeError: Dataset 'C://GithubProjects/AI-Powered-Road-Pothole-Detection/test/data.yaml' error  C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\data.yaml 'names' length 4 and 'nc: 1' must match.

# %%
# Resume Training
weight_path = "training/RDD_JapanIndia/Baseline_YOLOv8Small_Filtered2/weights/last.pt"

model_Trained = YOLO(weight_path) # pass any model type
results = model_Trained.train(
    resume=True
)

# %%
from ultralytics import YOLO

# -------------------------
# Training configuration
# -------------------------
_epoch = 100
_warmup_epochs = int(_epoch * 0.05)

_data = "C:\\GithubProjects\\AI-Powered-Road-Pothole-Detection\\test\\data.yaml"
_project = "runs/train"
_name = "yolov8_custom"

# -------------------------
# Load model
# -------------------------
model = YOLO("yolov8s.pt")  # pretrained weights

# -------------------------
# Train
# -------------------------
results = model.train(
    data=_data,
    epochs=_epoch,
    warmup_epochs=_warmup_epochs,
    batch=32,
    imgsz=640,
    save_period=10,
    workers=1,
    project=_project,
    name=_name,
    seed=1337,
    cos_lr=True,
    mosaic=0.0
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.252 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.251  Python-3.12.7 torch-2.9.1+cpu CPU (AMD Ryzen 7 7445HS w/ Radeon 740M Graphics)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=0.0, multi_scale=False, name=yolov8_custom4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\runs\detect\runs\train\yolov8_custom4, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=1337, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=1, workspace=None
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117596  ultralytics.nn.modules.head.Detect           [4, [128, 256, 512]]
# Model summary: 129 layers, 11,137,148 parameters, 11,137,132 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 102.630.9 MB/s, size: 68.7 KB)
# train: Scanning C:\Projects Datasets\Road-Pathole-Detection\processedData\train\labels\train.cache... 0 images, 9481 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 9481/9481 1.4Mit/s 0.0s
# WARNING Labels are missing or empty in C:\Projects Datasets\Road-Pathole-Detection\processedData\train\labels\train.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# val: Fast image access  (ping: 0.00.0 ms, read: 115.453.3 MB/s, size: 54.4 KB)
# val: Scanning C:\Projects Datasets\Road-Pathole-Detection\processedData\train\labels\val.cache... 0 images, 1054 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1054/1054  0.0s
# WARNING Labels are missing or empty in C:\Projects Datasets\Road-Pathole-Detection\processedData\train\labels\val.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# Plotting labels to C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\runs\detect\runs\train\yolov8_custom4\labels.jpg...
# WARNING zero-size array to reduction operation maximum which has no identity
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\GithubProjects\AI-Powered-Road-Pothole-Detection\test\runs\detect\runs\train\yolov8_custom4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G          0       1242          0          0        640: 1% ──────────── 2/297 1.8it/s 1:11<2:481

# %%
from ultralytics import YOLO

# %%
# japanIndia_Filtered
_data = "C:\Github Repo\AI-Powered-Road-Pothole-Detection\\test\data.yaml"
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\chanu\AppData\Local\Temp\ipykernel_18736\4001718894.py:2: SyntaxWarning: invalid escape sequence '\G'
#   _data = "C:\Github Repo\AI-Powered-Road-Pothole-Detection\\test\data.yaml"

# %%
weight_path = "C:\Github Repo\AI-Powered-Road-Pothole-Detection\model_data\\best.pt"

model = YOLO(weight_path)
metrics = model.val(data=_data)
# Out:
# Ultralytics 8.3.253  Python-3.12.12 torch-2.9.1+cpu CPU (AMD Ryzen 7 7445HS w/ Radeon 740M Graphics)
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\chanu\AppData\Local\Temp\ipykernel_18736\4152092563.py:1: SyntaxWarning: invalid escape sequence '\G'
#   weight_path = "C:\Github Repo\AI-Powered-Road-Pothole-Detection\model_data\\best.pt"
# Model summary (fused): 73 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 683.8161.7 MB/s, size: 70.3 KB)
# val: Scanning C:\Projects Datasets\RoadDamageDetection\handled_imbalance_processed_data\YOLOv8\RoadDamageDetection\labels\val.cache... 105 images, 14 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 105/105  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2s/it 15.5s2.6s
# ...
